# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.processing import StandardScaler

# %%
from sklearn.datasets import make_blobs

# %%
from sklearn.metrics import silhouette_score

# %%
import seaborn as sns

# %%
file_path = r'C:/Users/pc/OneDrive/Documents/Mall_Customers.csv'

# %%
df = pd.read_csv(file_path)

# %%
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df = df.dropna()

# %%
missing_values = df.isnull().sum()

# %%
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       0   19                  15                      39
# 1           2       0   21                  15                      81
# 2           3       1   20                  16                       6
# 3           4       1   23                  16                      77
# 4           5       1   31                  17                      40

# %%
basic_stats = df.describe()

# %%
plt.figure(figsize = (14, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['Age'], kde=True, bins=20)
plt.title('Age Distribution')
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt. subplot(1, 3, 2)
sns.histplot(df['Annual Income (k$)'], kde=True, bins=20)
plt. title('Annual Income Distribution')
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Annual Income Distribution')

# %%
plt.subplot(1,3,3)
sns.histplot(df['Spending Score (1-100)'], kde=True, bins=20)
plt.title('Spending Score Distribution')
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Spending Score Distribution')

# %%
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
features = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
X = df[features]

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
inertia = []
silhouette_scores = []

# %%
for n in range (2, 11):
    kmeans = KMeans(n_clusters=n, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)
    silthouette_scores.append(silhouette_score(X_scaled, kmeans.labels_))

# %%
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
inertia = []
K = range(2, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=0).fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
print(len(K))       
print(len(inertia))
# Out:
# 9
# 9

# %%
plt.figure(figsize=(14, 6))

# %%
plt.subplot(1, 2, 1)
plt.plot(K, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method For Optimal k')

# %%
inertia = []
silhouette_scores = []

# %%
K = range(2, 11)

# %%
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=0).fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
  if k > 1:
        score = silhouette_score(X, kmeans.labels_)
        silhouette_scores.append(score)

# %%
print(len(K))             
print(len(inertia))         
print(len(silhouette_scores))
# Out:
# 9
# 9
# 2

# %%
plt.figure(figsize=(14, 6))

# %%
plt.subplot(1, 2, 1)
plt.plot(K, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')

plt.subplot(1, 2, 2)
plt.plot(K[1:], silhouette_scores, marker='o')  
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores For Different k')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 8
#       5 plt.title('Elbow Method For Optimal k')
#       7 plt.subplot(1, 2, 2)
# ----> 8 plt.plot(K[1:], silhouette_scores, marker='o')  # K[1:] to match length of silhouette_scores
#       9 plt.xlabel('Number of Clusters')
#      10 plt.ylabel('Silhouette Score')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...

# %%
print("Length of K:", len(K))               
print("Length of inertia:", len(inertia))         
print("Length of silhouette_scores:", len(silhouette_scores))
# Out:
# Length of K: 9
# Length of inertia: 9
# Length of silhouette_scores: 2

# %%
# Plotting
plt.figure(figsize=(14, 6))

# Inertia plot
plt.subplot(1, 2, 1)
plt.plot(K, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')

# Silhouette Score plot
plt.subplot(1, 2, 2)
plt.plot(K[1:], silhouette_scores, marker='o')  # K[1:] to match length of silhouette_scores
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores For Different k')

# Show plots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 13
#      11 # Silhouette Score plot
#      12 plt.subplot(1, 2, 2)
# ---> 13 plt.plot(K[1:], silhouette_scores, marker='o')  # K[1:] to match length of silhouette_scores
#      14 plt.xlabel('Number of Clusters')
#      15 plt.ylabel('Silhouette Score')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(df[['Annual Income (k$)', 'Spending Score (1-100)']])
df['Cluster'] = kmeans.labels_
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
required_columns = ['Annual Income (k$)', 'Spending Score (1-100)', 'Cluster']
for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Column '{col}' is missing from DataFrame")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', palette='viridis')
plt.title('Customer Segments')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()
